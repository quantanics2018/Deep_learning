# %% [markdown]
# #Semantic  Image Segmentation Using CNN with Tensorflow and Keras
#
# Engaging in computer vision endeavors, specifically semantic segmentation, with the aim of developing a model proficient in discerning diverse clothing classes within arbitrary outdoor images featuring individuals.

# %% [markdown]
# ###About Dataset
#
# The People Clothing Dataset is tailored for Semantic Segmentation in Computer Vision, involving pixel-wise image classification into 59 distinct clothing classes. Comprising 1000 images and segmentation masks, the dataset emphasizes individual clothing items. Despite limited data, the modeling task is challenging.
#
# The standardized images (825x550 pixels in PNG format) require no preprocessing. Classes cover diverse clothing aspects like shirt, hair, pants, etc., with a background class. A provided CSV lists the classes. Notably, the dataset offers both JPEG and PNG formats, with PNG chosen for its lossless quality, preserving data originality.

# %% [markdown]
# ###Download Dataset or use kaggle API
#
#  "https://www.kaggle.com/datasets/rajkumarl/people-clothing-segmentation/"

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.5.16)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle) (2023.7.22)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.4)

# %%
# configuring the path of Kaggle.json file
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d rajkumarl/people-clothing-segmentation
# Out:
# Downloading people-clothing-segmentation.zip to /content
#  98% 601M/616M [00:08<00:00, 79.5MB/s]
# 100% 616M/616M [00:08<00:00, 75.3MB/s]

# %%
# !unzip people-clothing-segmentation.zip
# Out:
# Archive:  people-clothing-segmentation.zip
#   inflating: jpeg_images/IMAGES/img_0001.jpeg
#   inflating: jpeg_images/IMAGES/img_0002.jpeg
#   inflating: jpeg_images/IMAGES/img_0003.jpeg
#   inflating: jpeg_images/IMAGES/img_0004.jpeg
#   inflating: jpeg_images/IMAGES/img_0005.jpeg
#   inflating: jpeg_images/IMAGES/img_0006.jpeg
#   inflating: jpeg_images/IMAGES/img_0007.jpeg
#   inflating: jpeg_images/IMAGES/img_0008.jpeg
#   inflating: jpeg_images/IMAGES/img_0009.jpeg
#   inflating: jpeg_images/IMAGES/img_0010.jpeg
#   inflating: jpeg_images/IMAGES/img_0011.jpeg
#   inflating: jpeg_images/IMAGES/img_0012.jpeg
#   inflating: jpeg_images/IMAGES/img_0013.jpeg
#   inflating: jpeg_images/IMAGES/img_0014.jpeg
#   inflating: jpeg_images/IMAGES/img_0015.jpeg
#   inflating: jpeg_images/IMAGES/img_0016.jpeg
#   inflating: jpeg_images/IMAGES/img_0017.jpeg
#   inflating: jpeg_images/IMAGES/img_0018.jpeg
#   inflating: jpeg_images/IMAGES/img_0019.jpeg
#   inflating: jpeg_images/IMAGES/img_0020.jpeg
#   inflating: jpeg_images/IMAGES/img_0021.jpeg
#   inflating: jpeg_images/IMAGES/img_0022.jpeg
#   inflating: jpeg_images/IMAGES/img_0023.jpeg
#   inflating: jpeg_images/IMAGES/img_0024.jpeg
#   inflating: jpeg_images/IMAGES/img_0025.jpeg
#   inflating: jpeg_images/IMAGES/img_0026.jpeg
#   inflating: jpeg_images/IMAGES/img_0027.jpeg
#   inflating: jpeg_images/IMAGES/img_0028.jpeg
#   inflating: jpeg_images/IMAGES/img_0029.jpeg
#   inflating: jpeg_images/IMAGES/img_0030.jpeg
#   inflating: jpeg_images/IMAGES/img_0031.jpeg
#   inflating: jpeg_images/IMAGES/img_0032.jpeg
#   inflating: jpeg_images/IMAGES/img_0033.jpeg
#   inflating: png_masks/MASKS/seg_0949.png
#   inflating: png_masks/MASKS/seg_0950.png
#   inflating: png_masks/MASKS/seg_0951.png
#   inflating: png_masks/MASKS/seg_0952.png
#   inflating: png_masks/MASKS/seg_0953.png
#   inflating: png_masks/MASKS/seg_0954.png
#   inflating: png_masks/MASKS/seg_0955.png
#   inflating: png_masks/MASKS/seg_0956.png
#   inflating: png_masks/MASKS/seg_0957.png
#   inflating: png_masks/MASKS/seg_0958.png
#   inflating: png_masks/MASKS/seg_0959.png
#   inflating: png_masks/MASKS/seg_0960.png
#   inflating: png_masks/MASKS/seg_0961.png
#   inflating: png_masks/MASKS/seg_0962.png
#   inflating: png_masks/MASKS/seg_0963.png
#   inflating: png_masks/MASKS/seg_0964.png
#   inflating: png_masks/MASKS/seg_0965.png
#   inflating: png_masks/MASKS/seg_0966.png
#   inflating: png_masks/MASKS/seg_0967.png
#   inflating: png_masks/MASKS/seg_0968.png
#   inflating: png_masks/MASKS/seg_0969.png
#   inflating: png_masks/MASKS/seg_0970.png
#   inflating: png_masks/MASKS/seg_0971.png
#   inflating: png_masks/MASKS/seg_0972.png
#   inflating: png_masks/MASKS/seg_0973.png
#   inflating: png_masks/MASKS/seg_0974.png
#   inflating: png_masks/MASKS/seg_0975.png
#   inflating: png_masks/MASKS/seg_0976.png
#   inflating: png_masks/MASKS/seg_0977.png
#   inflating: png_masks/MASKS/seg_0978.png
#   inflating: png_masks/MASKS/seg_0979.png
#   inflating: png_masks/MASKS/seg_0980.png
#   inflating: png_masks/MASKS/seg_0981.png
#   inflating: png_masks/MASKS/seg_0982.png
#   inflating: png_masks/MASKS/seg_0983.png
#   inflating: png_masks/MASKS/seg_0984.png
#   inflating: png_masks/MASKS/seg_0985.png
#   inflating: png_masks/MASKS/seg_0986.png
#   inflating: png_masks/MASKS/seg_0987.png
#   inflating: png_masks/MASKS/seg_0988.png
#   inflating: png_masks/MASKS/seg_0989.png
#   inflating: png_masks/MASKS/seg_0990.png
#   inflating: png_masks/MASKS/seg_0991.png
#   inflating: png_masks/MASKS/seg_0992.png
#   inflating: png_masks/MASKS/seg_0993.png
#   inflating: png_masks/MASKS/seg_0994.png
#   inflating: png_masks/MASKS/seg_0995.png
#   inflating: png_masks/MASKS/seg_0996.png
#   inflating: png_masks/MASKS/seg_0997.png
#   inflating: png_masks/MASKS/seg_0998.png
#   inflating: png_masks/MASKS/seg_0999.png
#   inflating: png_masks/MASKS/seg_1000.png

# %%
# for path related functionalities
import os
import cv2
# for array operations
import numpy as np
# tensorflow framework
import tensorflow as tf
# keras API for deep learning
from tensorflow import keras
# for image visulaizations
import matplotlib.pyplot as plt
# for legends and other supporting functionalities
import matplotlib as mpl
# for viewing iteration status
from tqdm import tqdm

from sklearn.model_selection import train_test_split

# %%
# a list to collect paths of 1000 images
image_path = []
for root, dirs, files in os.walk('/content/png_images'):
    # iterate over 1000 images
    for file in files:
        # create path
        path = os.path.join(root,file)
        # add path to list
        image_path.append(path)
len(image_path)
# Out:
# 1000

# %%
# a list to collect paths of 1000 masks
mask_path = []
for root, dirs, files in os.walk('/content/png_masks'):
    #iterate over 1000 masks
    for file in files:
        # obtain the path
        path = os.path.join(root,file)
        # add path to the list
        mask_path.append(path)
len(mask_path)
# Out:
# 1000

# %% [markdown]
# # Sorting the datasets to get the right image-mask pairs

# %%
image_path.sort()
mask_path.sort()

# %% [markdown]
# # Decoding the images and masks to store them in seperate lists

# %%
# create a list to store images
images = []
# iterate over 1000 image paths
for path in tqdm(image_path):
    # read file
    file = tf.io.read_file(path)
    # decode png file into a tensor
    image = tf.image.decode_png(file, channels=3, dtype=tf.uint8)
    # append to the list
    images.append(image)


# create a list to store masks
masks = []
# iterate over 1000 mask paths
for path in tqdm(mask_path):
    # read the file
    file = tf.io.read_file(path)
    # decode png file into a tensor
    mask = tf.image.decode_png(file, channels=1, dtype=tf.uint8)
    # append mask to the list
    masks.append(mask)
# Out:
# 100%|██████████| 1000/1000 [00:09<00:00, 106.34it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 748.78it/s]

# %%
# length of images and masks
len(images), len(masks)
# Out:
# (1000, 1000)

# %% [markdown]
# # Visualizing a sample of the images and its corresponding mask

# %%
plt.figure(figsize=(25,13))
for i in range(10,13):
    plt.subplot(4,6,i)
    img = images[i]
    plt.imshow(img)
    plt.colorbar()
    plt.axis('off')
plt.show()

# %%
# Define a normalizer that can be applied while visualizing masks to have a consistency
# min class value is 0
# max class value is 58
NORM = mpl.colors.Normalize(vmin=0, vmax=58)

# plot masks
plt.figure(figsize=(25,13))
for i in range(10,13):
    plt.subplot(4,6,i)
    img = masks[i]
    plt.imshow(img, cmap='jet', norm=NORM)
    plt.colorbar()
    plt.axis('off')
plt.show()

# %% [markdown]
# # Preprocessing

# %%
#shape of an example image and mask
images[0].shape, masks[0].shape
# Out:
# (TensorShape([825, 550, 3]), TensorShape([825, 550, 1]))

# %%
#functions to resize the images and masks
def resize_image(image):
    # scale the image
    image = tf.cast(image, tf.float32)
    image = image/255.0
    # resize image
    image = tf.image.resize(image, (128,128))
    return image

def resize_mask(mask):
    # resize the mask
    mask = tf.image.resize(mask, (128,128))
    mask = tf.cast(mask, tf.uint8)
    return mask

# %%
X = [resize_image(i) for i in images]
y = [resize_mask(m) for m in masks]
len(X), len(y)
# Out:
# (1000, 1000)

# %%
#checking the datatypes
images[0].dtype, masks[0].dtype, X[0].dtype, y[0].dtype
# Out:
# (tf.uint8, tf.uint8, tf.float32, tf.uint8)

# %%
#visualizing a resized image and respective mask
# plot an image
plt.imshow(X[43])
plt.colorbar()
plt.show()

#plot a mask
plt.imshow(y[43], cmap='jet')
plt.colorbar()
plt.show()

# %% [markdown]
# # splitting into training and validation

# %%
# split data into 80/20 ratio
train_X, val_X,train_y, val_y = train_test_split(X, y, test_size=0.2,
                                                      random_state=0
                                                     )
# develop tf Dataset objects
train_X = tf.data.Dataset.from_tensor_slices(train_X)
val_X = tf.data.Dataset.from_tensor_slices(val_X)

train_y = tf.data.Dataset.from_tensor_slices(train_y)
val_y = tf.data.Dataset.from_tensor_slices(val_y)

# verify the shapes and data types
train_X.element_spec, train_y.element_spec, val_X.element_spec, val_y.element_spec
# Out:
# (TensorSpec(shape=(128, 128, 3), dtype=tf.float32, name=None),
#  TensorSpec(shape=(128, 128, 1), dtype=tf.uint8, name=None),
#  TensorSpec(shape=(128, 128, 3), dtype=tf.float32, name=None),
#  TensorSpec(shape=(128, 128, 1), dtype=tf.uint8, name=None))

# %% [markdown]
# # Data Augmentation
# To Increase Training Data

# %%
# adjust brightness of image
# don't alter in mask
def brightness(img, mask):
    img = tf.image.adjust_brightness(img, 0.1)
    return img, mask

# adjust gamma of image
# don't alter in mask
def gamma(img, mask):
    img = tf.image.adjust_gamma(img, 0.1)
    return img, mask

# adjust hue of image
# don't alter in mask
def hue(img, mask):
    img = tf.image.adjust_hue(img, -0.1)
    return img, mask

def crop(img, mask):
    # crop both image and mask identically
    img = tf.image.central_crop(img, 0.7)
    # resize after cropping
    img = tf.image.resize(img, (128,128))
    mask = tf.image.central_crop(mask, 0.7)
    # resize afer cropping
    mask = tf.image.resize(mask, (128,128))
    # cast to integers as they are class numbers
    mask = tf.cast(mask, tf.uint8)
    return img, mask

# flip both image and mask identically
def flip_hori(img, mask):
    img = tf.image.flip_left_right(img)
    mask = tf.image.flip_left_right(mask)
    return img, mask

# flip both image and mask identically
def flip_vert(img, mask):
    img = tf.image.flip_up_down(img)
    mask = tf.image.flip_up_down(mask)
    return img, mask

# rotate both image and mask identically
def rotate(img, mask):
    img = tf.image.rot90(img)
    mask = tf.image.rot90(mask)
    return img, mask

# %% [markdown]
# Perform data augmentation with original training set and concatenate with enlarged training set. Which will give us, with 7 functions, 7*800=5600 plus the original 800, total 6400.

# %%
# zip images and masks
train = tf.data.Dataset.zip((train_X, train_y))
val = tf.data.Dataset.zip((val_X, val_y))

# perform augmentation on train data only

a = train.map(brightness)
b = train.map(gamma)
c = train.map(hue)
d = train.map(crop)
e = train.map(flip_hori)
f = train.map(flip_vert)
g = train.map(rotate)

# concatenate every new augmented sets
train = train.concatenate(a)
train = train.concatenate(b)
train = train.concatenate(c)
train = train.concatenate(d)
train = train.concatenate(e)
train = train.concatenate(f)
train = train.concatenate(g)

# %%
#setting the batch size
BATCH = 64

AT = tf.data.AUTOTUNE
#buffersize
BUFFER = 1000

STEPS_PER_EPOCH = 800//BATCH
VALIDATION_STEPS = 200//BATCH

train = train.cache().shuffle(BUFFER).batch(BATCH).repeat()
train = train.prefetch(buffer_size=AT)
val = val.batch(BATCH)

# %% [markdown]
# # Building the Model
# We will use FCNN(Fully Convolutional Neural Networks) which contains two parts: an encoder and a decoder. An encoder is a downstack of convolutional neural layers that extract features from the input image. A decoder is an upstack of transpose convolutional neural layers that builds the segmented image from the extracted features.
# In this project we will use the U-Net architecture

# %% [markdown]
# We wish to use the functional approach of U-Net architecture, but we will have our own architecture suitable to our task. The downstack can be a pre-trained CNN, trained for image classification (e.g. MobileNetV2, ResNet, NASNet, Inception, DenseNet, or EfficientNet). It can effectively extract the features. But, we have to build our upstack to match our classes (here, 59), build skip-connections, and train it with our data.

# %%
# Use pre-trained DenseNet121 without head
base = keras.applications.DenseNet121(input_shape=[128,128,3],
                                      include_top=False,
                                      weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 0s 0us/step

# %%
#length of layers
len(base.layers)
# Out:
# 427

# %%
#final ReLU activation layer for each feature map size, i.e. 4, 8, 16, 32, and 64, required for skip-connections
skip_names = ['conv1/relu', # size 64*64
             'pool2_relu',  # size 32*32
             'pool3_relu',  # size 16*16
             'pool4_relu',  # size 8*8
             'relu'        # size 4*4
             ]

# %%
#output of these layers
skip_outputs = [base.get_layer(name).output for name in skip_names]
for i in range(len(skip_outputs)):
    print(skip_outputs[i])
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 64, 64, 64), dtype=tf.float32, name=None), name='conv1/relu/Relu:0', description="created by layer 'conv1/relu'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 32, 32, 256), dtype=tf.float32, name=None), name='pool2_relu/Relu:0', description="created by layer 'pool2_relu'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 16, 16, 512), dtype=tf.float32, name=None), name='pool3_relu/Relu:0', description="created by layer 'pool3_relu'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 8, 8, 1024), dtype=tf.float32, name=None), name='pool4_relu/Relu:0', description="created by layer 'pool4_relu'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 4, 4, 1024), dtype=tf.float32, name=None), name='relu/Relu:0', description="created by layer 'relu'")

# %%
#Building the downstack with the above layers. We use the pre-trained model as such, without any fine-tuning.
downstack = keras.Model(inputs=base.input,
                       outputs=skip_outputs)
# freeze the downstack layers
downstack.trainable = False

# %% [markdown]
# # Building the Upstack

# %% [markdown]
# Building the upstack using an upsampling template. Let's use pix2pix template available open-source in tensorflow_examples repository

# %%
# !pip install -q git+https://github.com/tensorflow/examples.git --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for tensorflow-examples (setup.py) ... done

# %%
from tensorflow_examples.models.pix2pix import pix2pix

# Four upstack layers for upsampling sizes
# 4->8, 8->16, 16->32, 32->64
upstack = [pix2pix.upsample(512,3),
          pix2pix.upsample(256,3),
          pix2pix.upsample(128,3),
          pix2pix.upsample(64,3)]

# %%
upstack[1].layers
# Out:
# [<keras.src.layers.convolutional.conv2d_transpose.Conv2DTranspose at 0x7c73b0742c50>,
#  <keras.src.layers.normalization.batch_normalization.BatchNormalization at 0x7c73b0743250>,
#  <keras.src.layers.activation.relu.ReLU at 0x7c73a0393b50>]

# %% [markdown]
# # Building the U-Net model with skip connections
# Merging the downstack and upstack with skip-connections

# %%
# define the input layer
inputs = keras.layers.Input(shape=[128,128,3])

# downsample
down = downstack(inputs)
out = down[-1]

# prepare skip-connections
skips = reversed(down[:-1])
# choose the last layer at first 4 --> 8

# upsample with skip-connections
for up, skip in zip(upstack,skips):
    out = up(out)
    out = keras.layers.Concatenate()([out,skip])

# define the final transpose conv layer
# image 128 by 128 with 59 classes
out = keras.layers.Conv2DTranspose(59, 3,
                                  strides=2,
                                  padding='same',
                                  )(out)
# complete unet model
unet = keras.Model(inputs=inputs, outputs=out)

# %%
#checking for model and data compatibility
# infer on train dataset
example = next(iter(train))
preds = unet(example[0])

# visualize an image
plt.imshow(example[0][60])
plt.colorbar()
plt.show()

# %%
# visualize the predicted mask
pred_mask = tf.argmax(preds, axis=-1)
pred_mask = tf.expand_dims(pred_mask, -1)
plt.imshow(pred_mask[0], cmap='jet', norm=NORM)
plt.colorbar()

# %%
# compiling the model
def Compile_Model():
    unet.compile(loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
            optimizer=keras.optimizers.RMSprop(learning_rate=0.001),
            metrics=['accuracy'])
Compile_Model()

# %%
#training and fine-tuning
hist_1 = unet.fit(train,
               validation_data=val,
               steps_per_epoch=STEPS_PER_EPOCH,
               validation_steps=VALIDATION_STEPS,
               epochs=20,
               verbose=2)
# Out:
# Epoch 1/20
# 12/12 - 143s - loss: 2.9369 - accuracy: 0.5955 - val_loss: 3.6058 - val_accuracy: 0.7470 - 143s/epoch - 12s/step
# Epoch 2/20
# 12/12 - 131s - loss: 1.7757 - accuracy: 0.7627 - val_loss: 3.1352 - val_accuracy: 0.7643 - 131s/epoch - 11s/step
# Epoch 3/20
# 12/12 - 129s - loss: 1.3214 - accuracy: 0.7696 - val_loss: 2.7282 - val_accuracy: 0.7665 - 129s/epoch - 11s/step
# Epoch 4/20
# 12/12 - 125s - loss: 1.3642 - accuracy: 0.7109 - val_loss: 2.1830 - val_accuracy: 0.7691 - 125s/epoch - 10s/step
# Epoch 5/20
# 12/12 - 131s - loss: 1.2762 - accuracy: 0.7089 - val_loss: 1.9214 - val_accuracy: 0.7731 - 131s/epoch - 11s/step
# Epoch 6/20
# 12/12 - 128s - loss: 1.0798 - accuracy: 0.7492 - val_loss: 1.6070 - val_accuracy: 0.7705 - 128s/epoch - 11s/step
# Epoch 7/20
# 12/12 - 129s - loss: 1.0101 - accuracy: 0.7660 - val_loss: 1.4270 - val_accuracy: 0.7776 - 129s/epoch - 11s/step
# Epoch 8/20
# 12/12 - 128s - loss: 0.9464 - accuracy: 0.7748 - val_loss: 1.2540 - val_accuracy: 0.7759 - 128s/epoch - 11s/step
# Epoch 9/20
# 12/12 - 128s - loss: 0.8434 - accuracy: 0.7911 - val_loss: 1.1274 - val_accuracy: 0.7811 - 128s/epoch - 11s/step
# Epoch 10/20
# 12/12 - 128s - loss: 0.7939 - accuracy: 0.8011 - val_loss: 1.0249 - val_accuracy: 0.7863 - 128s/epoch - 11s/step
# Epoch 11/20
# 12/12 - 129s - loss: 0.7891 - accuracy: 0.8008 - val_loss: 0.9505 - val_accuracy: 0.7754 - 129s/epoch - 11s/step
# Epoch 12/20
# 12/12 - 128s - loss: 0.9014 - accuracy: 0.7743 - val_loss: 0.9407 - val_accuracy: 0.7831 - 128s/epoch - 11s/step
# Epoch 13/20
# 12/12 - 125s - loss: 1.0370 - accuracy: 0.7452 - val_loss: 0.9047 - val_accuracy: 0.7816 - 125s/epoch - 10s/step
# Epoch 14/20
# 12/12 - 129s - loss: 0.9024 - accuracy: 0.7736 - val_loss: 0.8640 - val_accuracy: 0.7902 - 129s/epoch - 11s/step
# Epoch 15/20
# 12/12 - 129s - loss: 0.8359 - accuracy: 0.7894 - val_loss: 0.8571 - val_accuracy: 0.8030 - 129s/epoch - 11s/step
# Epoch 16/20
# 12/12 - 128s - loss: 0.7953 - accuracy: 0.7962 - val_loss: 0.8292 - val_accuracy: 0.7965 - 128s/epoch - 11s/step
# Epoch 17/20
# 12/12 - 128s - loss: 0.7318 - accuracy: 0.8102 - val_loss: 0.8026 - val_accuracy: 0.7977 - 128s/epoch - 11s/step
# Epoch 18/20
# 12/12 - 124s - loss: 0.6550 - accuracy: 0.8267 - val_loss: 0.7938 - val_accuracy: 0.8007 - 124s/epoch - 10s/step
# Epoch 19/20
# 12/12 - 128s - loss: 0.6866 - accuracy: 0.8198 - val_loss: 0.7789 - val_accuracy: 0.7998 - 128s/epoch - 11s/step
# Epoch 20/20
# 12/12 - 128s - loss: 0.7101 - accuracy: 0.8156 - val_loss: 0.7581 - val_accuracy: 0.8144 - 128s/epoch - 11s/step

# %% [markdown]
# <b>Making a Prediction

# %%
# select a validation data batch
img, mask = next(iter(val))
# make prediction
pred = unet.predict(img)
plt.figure(figsize=(20,28))

k = 0
for i in pred:
    # plot the predicted mask
    plt.subplot(4,3,1+k*3)
    i = tf.argmax(i, axis=-1)
    plt.imshow(i,cmap='jet', norm=NORM)
    plt.axis('off')
    plt.title('Prediction')

    # plot the groundtruth mask
    plt.subplot(4,3,2+k*3)
    plt.imshow(mask[k], cmap='jet', norm=NORM)
    plt.axis('off')
    plt.title('Ground Truth')

    # plot the actual image
    plt.subplot(4,3,3+k*3)
    plt.imshow(img[k])
    plt.axis('off')
    plt.title('Actual Image')
    k += 1
    if k == 4: break
plt.suptitle('Predition After 20 Epochs (No Fine-tuning)', color='red', size=20)
plt.show()
# Out:
# 2/2 [==============================] - 12s 4s/step

# %%
downstack.trainable = True
# compile again
Compile_Model()
# train from epoch 20 to 40
hist_2 = unet.fit(train,
               validation_data=val,
               steps_per_epoch=STEPS_PER_EPOCH,
               validation_steps=VALIDATION_STEPS,
               epochs=40, initial_epoch = 20,
               verbose = 2
                 )
# Out:
# Epoch 21/40
# 12/12 - 229s - loss: 0.6757 - accuracy: 0.8265 - val_loss: 0.7176 - val_accuracy: 0.8194 - 229s/epoch - 19s/step
# Epoch 22/40
# 12/12 - 207s - loss: 0.5850 - accuracy: 0.8465 - val_loss: 0.7344 - val_accuracy: 0.8132 - 207s/epoch - 17s/step
# Epoch 23/40
# 12/12 - 204s - loss: 0.5617 - accuracy: 0.8526 - val_loss: 0.7423 - val_accuracy: 0.8154 - 204s/epoch - 17s/step
# Epoch 24/40
# 12/12 - 200s - loss: 0.7868 - accuracy: 0.8039 - val_loss: 0.7204 - val_accuracy: 0.8186 - 200s/epoch - 17s/step
# Epoch 25/40
# 12/12 - 207s - loss: 0.7533 - accuracy: 0.8111 - val_loss: 0.7857 - val_accuracy: 0.8084 - 207s/epoch - 17s/step
# Epoch 26/40
# 12/12 - 204s - loss: 0.6885 - accuracy: 0.8242 - val_loss: 0.8626 - val_accuracy: 0.7998 - 204s/epoch - 17s/step
# Epoch 27/40
# 12/12 - 205s - loss: 0.6598 - accuracy: 0.8300 - val_loss: 0.8854 - val_accuracy: 0.7971 - 205s/epoch - 17s/step
# Epoch 28/40
# 12/12 - 202s - loss: 0.5984 - accuracy: 0.8413 - val_loss: 0.8185 - val_accuracy: 0.8039 - 202s/epoch - 17s/step
# Epoch 29/40
# 12/12 - 201s - loss: 0.5080 - accuracy: 0.8648 - val_loss: 0.6887 - val_accuracy: 0.8245 - 201s/epoch - 17s/step
# Epoch 30/40
# 12/12 - 205s - loss: 0.4608 - accuracy: 0.8770 - val_loss: 0.6253 - val_accuracy: 0.8387 - 205s/epoch - 17s/step
# Epoch 31/40
# 12/12 - 206s - loss: 0.4418 - accuracy: 0.8832 - val_loss: 0.6370 - val_accuracy: 0.8359 - 206s/epoch - 17s/step
# Epoch 32/40
# 12/12 - 205s - loss: 0.5777 - accuracy: 0.8523 - val_loss: 0.6449 - val_accuracy: 0.8368 - 205s/epoch - 17s/step
# Epoch 33/40
# 12/12 - 204s - loss: 0.7011 - accuracy: 0.8256 - val_loss: 0.6557 - val_accuracy: 0.8356 - 204s/epoch - 17s/step
# Epoch 34/40
# 12/12 - 205s - loss: 0.5719 - accuracy: 0.8522 - val_loss: 0.7800 - val_accuracy: 0.8193 - 205s/epoch - 17s/step
# Epoch 35/40
# 12/12 - 205s - loss: 0.5350 - accuracy: 0.8594 - val_loss: 0.6597 - val_accuracy: 0.8373 - 205s/epoch - 17s/step
# Epoch 36/40
# 12/12 - 205s - loss: 0.5100 - accuracy: 0.8645 - val_loss: 0.8281 - val_accuracy: 0.8117 - 205s/epoch - 17s/step
# Epoch 37/40
# 12/12 - 205s - loss: 0.4773 - accuracy: 0.8736 - val_loss: 0.5761 - val_accuracy: 0.8513 - 205s/epoch - 17s/step
# Epoch 38/40
# 12/12 - 205s - loss: 0.3741 - accuracy: 0.9012 - val_loss: 0.5776 - val_accuracy: 0.8504 - 205s/epoch - 17s/step
# Epoch 39/40
# 12/12 - 204s - loss: 0.3783 - accuracy: 0.8997 - val_loss: 0.6141 - val_accuracy: 0.8446 - 204s/epoch - 17s/step
# Epoch 40/40
# 12/12 - 204s - loss: 0.4025 - accuracy: 0.8970 - val_loss: 0.6035 - val_accuracy: 0.8502 - 204s/epoch - 17s/step

# %% [markdown]
# <b>Making a Prediction

# %%
# select a validation data batch
img, mask = next(iter(val))
# make prediction
pred = unet.predict(img)
plt.figure(figsize=(20,30))

k = 0
for i in pred:
    # plot the predicted mask
    plt.subplot(4,3,1+k*3)
    i = tf.argmax(i, axis=-1)
    plt.imshow(i,cmap='jet', norm=NORM)
    plt.axis('off')
    plt.title('Prediction')

    # plot the groundtruth mask
    plt.subplot(4,3,2+k*3)
    plt.imshow(mask[k], cmap='jet', norm=NORM)
    plt.axis('off')
    plt.title('Ground Truth')

    # plot the actual image
    plt.subplot(4,3,3+k*3)
    plt.imshow(img[k])
    plt.axis('off')
    plt.title('Actual Image')
    k += 1
    if k == 4: break
plt.suptitle('Predition After 40 Epochs (By Fine-tuning from 21th Epoch)', color='red', size=20)
plt.show()
# Out:
# 2/2 [==============================] - 5s 3s/step

# %% [markdown]
# <b>The model has improved significantly

# %% [markdown]
# # Performance Curves

# %%
history_1 = hist_1.history
acc=history_1['accuracy']
val_acc = history_1['val_accuracy']

history_2 = hist_2.history
acc.extend(history_2['accuracy'])
val_acc.extend(history_2['val_accuracy'])

plt.plot(acc[:150], '-', label='Training')
plt.plot(val_acc[:150], '--', label='Validation')
plt.plot([50,50],[0.7,1.0], '--g', label='Fine-Tuning')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.ylim([0.7,1.0])
plt.legend()
plt.show()
